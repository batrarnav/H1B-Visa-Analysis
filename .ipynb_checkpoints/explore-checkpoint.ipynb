# %% [markdown]
# # H1B Visa Analysis
#
# ## Author: Muskan Vaswan, Arnav Batra

# %% [markdown]
# Dataset Description:
# H-1B visas are a category of employment-based, non-immigrant visas for temporary foreign workers in the United States. For a foreign national to apply for H1-B visa, a US employer must offer them a job and submit a petition for a H-1B visa to the US immigration department. This is also the most common visa status applied for and held by international students once they complete college or higher education and begin working in a full-time position.
#
# https://www.kaggle.com/nsharan/h-1b-visa

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})


h1b_visa = pd.read_csv('h1b_kaggle.csv')

# %%
h1b_visa.head()
# Out:
#    Unnamed: 0          CASE_STATUS  \
# 0           1  CERTIFIED-WITHDRAWN
# 1           2  CERTIFIED-WITHDRAWN
# 2           3  CERTIFIED-WITHDRAWN
# 3           4  CERTIFIED-WITHDRAWN
# 4           5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE  \
# 0                  N          36067.0  2016.0      ANN ARBOR, MICHIGAN
# 1                  Y         242674.0  2016.0             PLANO, TEXAS
# 2                  Y         193066.0  2016.0  JERSEY CITY, NEW JERSEY
# 3                  Y         220314.0  2016.0         DENVER, COLORADO
# 4                  Y         157518.4  2016.0      ST. LOUIS, MISSOURI
#
#           lon        lat
# 0  -83.743038  42.280826
# 1  -96.698886  33.019843
# 2  -74.077642  40.728158
# 3 -104.990251  39.739236
# 4  -90.199404  38.627003

# %%
# Columns in data frame
print('\n'.join(list(h1b_visa.columns)[1:]))
# Out:
# CASE_STATUS
# EMPLOYER_NAME
# SOC_NAME
# JOB_TITLE
# FULL_TIME_POSITION
# PREVAILING_WAGE
# YEAR
# WORKSITE
# lon
# lat

# %%
# Number of Rows in the database 
h1b_visa.shape[0]
# Out:
# 3002458

# %%
# Variety of case statuses
statuses = h1b_visa['CASE_STATUS'].value_counts()
statuses
# Out:
# CERTIFIED                                             2615623
# CERTIFIED-WITHDRAWN                                    202659
# DENIED                                                  94346
# WITHDRAWN                                               89799
# PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED         15
# REJECTED                                                    2
# INVALIDATED                                                 1
# Name: CASE_STATUS, dtype: int64

# %%
statuses.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
h1b_visa['YEAR'].value_counts()
# Out:
# 2016.0    647803
# 2015.0    618727
# 2014.0    519427
# 2013.0    442114
# 2012.0    415607
# 2011.0    358767
# Name: YEAR, dtype: int64

# %%
employers = h1b_visa['EMPLOYER_NAME'].value_counts()
top_employers = employers[:1200]

# %%
sum(employers)
# Out:
# 3002399

# %%
sum(top_employers)
# Out:
# 1512784

# %%
# Percentage of applications by top 20 employers

sum(top_employers) / sum(employers) * 100
# Out:
# 50.38584145544945

# %%
# Percentage of top employers that employers

len(top_employers) / len(employers) * 100
# Out:
# 0.5084465686212201

# %% [markdown]
# Key points:
#
# 1. Top 20 companies account for 18.5% of all apllications.
# 2. Top 0.5% of companies account for more than 50% of all apllications.

# %% [markdown]
# ### Analysing a dataset of countries
#
# https://www.kaggle.com/peopledatalabssf/free-7-million-company-dataset?select=companies_sorted.csv

# %%
companies = pd.read_csv('companies_sorted.csv')
companies.head()
# Out:
#    Unnamed: 0                       name         domain  year founded  \
# 0     5872184                        ibm        ibm.com        1911.0
# 1     4425416  tata consultancy services        tcs.com        1968.0
# 2       21074                  accenture  accenture.com        1989.0
# 3     2309813                    us army     goarmy.com        1800.0
# 4     1558607                         ey         ey.com        1989.0
#
#                               industry size range  \
# 0  information technology and services     10001+
# 1  information technology and services     10001+
# 2  information technology and services     10001+
# 3                             military     10001+
# 4                           accounting     10001+
#
#                                  locality         country  \
# 0       new york, new york, united states   united states
# 1              bombay, maharashtra, india           india
# 2                 dublin, dublin, ireland         ireland
# 3     alexandria, virginia, united states   united states
# 4  london, greater london, united kingdom  united kingdom
#
#                                      linkedin url  current employee estimate  \
# 0                        linkedin.com/company/ibm                     274047
# 1  linkedin.com/company/tata-consultancy-services                     190771
# 2                  linkedin.com/company/accenture                     190689
# 3                    linkedin.com/company/us-army                     162163
# 4              linkedin.com/company/ernstandyoung                     158363
#
#    total employee estimate
# 0                   716906
# 1                   341369
# 2                   455768
# 3                   445958
# 4                   428960

# %%
companies.shape[0]
# Out:
# 7173426

# %%
companies['industry'].value_counts()
# Out:
# information technology and services    453044
# marketing and advertising              338162
# construction                           257921
# management consulting                  194556
# real estate                            193486
#                                         ...
# fishery                                  2355
# ranching                                 2324
# railroad manufacture                     1818
# tobacco                                  1354
# legislative office                        524
# Name: industry, Length: 148, dtype: int64

# %%
top_employers.index
# Out:
# Index(['INFOSYS LIMITED', 'TATA CONSULTANCY SERVICES LIMITED', 'WIPRO LIMITED',
#        'DELOITTE CONSULTING LLP', 'IBM INDIA PRIVATE LIMITED', 'ACCENTURE LLP',
#        'MICROSOFT CORPORATION', 'HCL AMERICA, INC.', 'ERNST & YOUNG U.S. LLP',
#        'COGNIZANT TECHNOLOGY SOLUTIONS U.S. CORPORATION',
#        ...
#        'APPDYNAMICS, INC.', 'INTELLISOFT TECHNOLOGIES, INC.',
#        'IT DIVISION, INC.', 'MILLENNIUM SOFTWARE, INC.',
#        'SKYWORKS SOLUTIONS, INC.', 'TECHNICAL STRATEGIES INC',
#        'VALUELABS, INC.', 'ARICENT TECHNOLOGIES (HOLDINGS) LIMITED',
#        'HANUSOFT INC', 'OASYS TECHNOLOGIES INC'],
#       dtype='object', length=1200)

# %%
top_company_names = [name.lower() for name in list(top_employers.index)]

# %%
top_company_names
# Out:
# ['infosys limited',
#  'tata consultancy services limited',
#  'wipro limited',
#  'deloitte consulting llp',
#  'ibm india private limited',
#  'accenture llp',
#  'microsoft corporation',
#  'hcl america, inc.',
#  'ernst & young u.s. llp',
#  'cognizant technology solutions u.s. corporation',
#  'larsen & toubro infotech limited',
#  'capgemini america inc',
#  'google inc.',
#  'ibm corporation',
#  'igate technologies inc.',
#  'intel corporation',
#  'tech mahindra (americas),inc.',
#  'deloitte & touche llp',
#  'amazon corporate llc',
#  'oracle america, inc.',
#  'apple inc.',
#  'jpmorgan chase & co.',
#  'tech mahindra (americas), inc.',
#  'ust global inc.',
#  'ust global inc',
#  'qualcomm technologies, inc.',
#  'hexaware technologies, inc.',
#  'fujitsu america, inc.',
#  'mastech, inc., a mastech holdings, inc. company',
#  'mphasis corporation',
#  'cummins inc.',
#  'kpmg llp',
#  'ntt data, inc.',
#  'emc corporation',
#  'capgemini financial services usa inc',
#  'v-soft consulting group, inc',
#  'bank of america n.a.',
#  'facebook, inc.',
#  'mindtree limited',
#  'qualcomm incorporated',
#  'synechron, inc.',
#  'l&t technology services limited',
#  'goldman, sachs & co.',
#  'capgemini u.s. llc',
#  'hcl global systems inc',
#  'wal-mart associates, inc.',
#  'ebay inc.',
#  'randstad technologies, lp',
#  'compunnel software group, inc.',
#  'ericsson inc.',
#  'yahoo! inc.',
#  'persistent systems, inc.',
#  'syntel consulting inc.',
#  'patni americas inc.',
#  'cisco systems, inc.',
#  'kpit infosystems, inc.',
#  'system soft technologies llc',
#  'larsen & toubro limited',
#  'university of michigan',
#  'broadcom corporation',
#  'hitachi consulting corporation',
#  'paypal, inc.',
#  'capital one services, llc',
#  'cvs rx services, inc.',
#  'pricewaterhousecoopers llp',
#  'populus group',
#  'htc global services inc.',
#  'marlabs, inc',
#  'vmware, inc.',
#  'headstrong services llc',
#  'credit suisse securities (usa) llc',
#  'pricewaterhousecoopers, llp',
#  'deloitte tax llp',
#  'itech us, inc.',
#  'satyam computer services limited',
#  'birlasoft inc',
#  'bloomberg, lp',
#  'national institutes of health, hhs',
#  'schlumberger technology corporation',
#  'symantec corporation',
#  'cerner corporation',
#  'trustees of the university of pennsylvania',
#  'csc covansys corporation',
#  'salesforce.com, inc.',
#  'sapient corporation',
#  'virtusa corporation',
#  'yash technologies, inc.',
#  'linkedin corporation',
#  'citibank, n.a.',
#  'tech mahindra (americas) inc.',
#  'ciber, inc.',
#  '3i infotech, inc.',
#  'the mathworks, inc.',
#  'management health systems, inc.',
#  'cgi technologies and solutions inc.',
#  'reliable software resources, inc.',
#  'harvard university',
#  'astir it solutions inc.',
#  'syntel inc',
#  'micron technology, inc.',
#  'merrill lynch',
#  'netapp, inc.',
#  'itc infotech (usa), inc.',
#  'yale university',
#  'columbia university',
#  'johns hopkins university',
#  'erp analysts, inc.',
#  'texas instruments incorporated',
#  'mayo clinic',
#  'horizon technologies inc',
#  'dallas independent school district',
#  'pricewaterhousecoopers advisory services llc',
#  'lead it corporation',
#  'satyam computer services ltd.',
#  'emory university',
#  'morgan stanley & co. llc',
#  'baylor college of medicine',
#  'rjt compuquest, inc.',
#  'experis us, inc.',
#  'hewlett-packard company',
#  'verizon data services llc',
#  'university of pittsburgh',
#  'marvell semiconductor, inc.',
#  'technosoft corporation',
#  'satyam computer services ltd',
#  'cyberthink inc',
#  'barclays services corp.',
#  'university of colorado',
#  'kforce inc.',
#  'the ohio state university',
#  'rite aid corp.',
#  'washington university in st. louis',
#  'intone networks inc.',
#  'exilant technologies private limited',
#  'the university of iowa',
#  'eclinicalworks, llc',
#  'dell marketing l.p.',
#  'oracle financial services software, inc.',
#  'advanced micro devices, inc.',
#  'multivision inc.',
#  't-mobile usa, inc.',
#  'sap america, inc.',
#  'tesla motors, inc.',
#  'sunera technologies, inc',
#  'northwestern university',
#  'citigroup global markets inc.',
#  'university of florida',
#  'general hospital corporation',
#  'avco consulting inc',
#  'idhasoft, inc.',
#  'diaspark, inc.',
#  'intuit inc.',
#  'globalfoundries u.s. inc.',
#  'grandison management, inc.',
#  'larsen & toubro technology services ltd',
#  'smartplay, inc.',
#  'yash & lujan consulting, inc.',
#  'akvarr inc',
#  'perficient, inc.',
#  'idexcel, inc.',
#  'american information technology corporation',
#  'university of maryland college park',
#  'university of minnesota',
#  'the boston consulting group, inc.',
#  'university of california, san francisco',
#  'massachusetts institute of technology',
#  'niit technologies limited',
#  'infosys technologies limited',
#  'university of california, davis',
#  'prokarma, inc.',
#  'duke university and medical center',
#  'twitter, inc.',
#  'polaris software lab (india) ltd.',
#  'genesis eldercare rehabilitation services, inc.',
#  'expedia, inc.',
#  'the univ. of ala. at birmingham (uab)',
#  'ibm india pvt. ltd.',
#  'cyient, inc.',
#  'the university of chicago',
#  'the university of texas at austin',
#  'vedicsoft solutions llc',
#  'qualcomm atheros, inc.',
#  'cyma systems inc',
#  'intraedge, inc.',
#  'verinon technology solutions ltd.',
#  'photon infotech, inc.',
#  'comcast cable communications, llc',
#  'smartsoft international, inc.',
#  'collaborate solutions inc',
#  'university of california, san diego',
#  'at&t services, inc.',
#  'university of illinois',
#  'michigan state university',
#  'charter global, inc.',
#  'university of washington',
#  'nvidia corporation',
#  'university of california, los angeles',
#  'tech mahindra ( americas), inc',
#  'deutsche bank securities inc.',
#  'vedicsoft',
#  'adobe systems incorporated',
#  'htc global services, inc.',
#  'orion systems integrators, inc',
#  'microexcel, inc',
#  'cmc americas, inc.',
#  'srs consulting inc.',
#  'hp enterprise services, llc',
#  'natsoft corporation',
#  'howard hughes medical institute',
#  'university of illinois at chicago',
#  'new york university school of medicine',
#  'dotcom team, llc',
#  'people tech group inc.',
#  "brigham and women's hospital",
#  'university of wisconsin-madison',
#  'mount sinai medical center',
#  'hsbc bank usa, n.a.',
#  'sears holdings management corporation',
#  'mckinsey & company, inc. united states',
#  'akamai technologies, inc.',
#  'computer sciences corporation',
#  'inovant, llc',
#  'sagarsoft, inc',
#  'memorial sloan-kettering cancer center',
#  'purdue university',
#  'university of utah',
#  'apex technology systems, inc',
#  'pyramid technology solutions, inc',
#  'battelle',
#  'medtronic, inc.',
#  'advent global solutions inc.',
#  'blackrock financial management, inc.',
#  'genpact llc',
#  'alindus, inc.',
#  'american express travel related services company, inc.',
#  'citrix systems, inc.',
#  'the pennsylvania state university',
#  'siri infosolutions inc.',
#  'the university of arizona',
#  'software paradigms international group, llc',
#  'techdemocracy llc',
#  'a2z development center, inc.',
#  'brookhaven national laboratory',
#  'amdocs inc.',
#  "children's hospital corporation",
#  'baltimore city public schools',
#  'indiana univ. purdue univ. indianapolis',
#  'avant healthcare professionals',
#  'uber technologies, inc.',
#  'engineering technology associates, inc.',
#  'texas a&m university',
#  'gss infotech ct, inc.',
#  'citiustech inc.',
#  'sandisk corporation',
#  'tringapps inc',
#  'motorola mobility llc',
#  'proficient business systems, inc.',
#  'sparta consulting inc.',
#  'vanderbilt university',
#  'sudhi infomatics inc',
#  'populus group llc',
#  'kla-tencor corporation',
#  'university of north carolina at chapel hill',
#  'ipolarity llc',
#  'sage it, inc.',
#  'fidelity technology group llc',
#  'delasoft, inc.',
#  'general motors company',
#  'vsquare infotech inc.',
#  'state university of new york at buffalo',
#  'brocade communications systems, inc.',
#  'case western reserve university',
#  'university of california, berkeley',
#  'the university of texas m.d. anderson cancer cente',
#  'the university of southern california',
#  'indiana university',
#  'infotech enterprises america, inc.',
#  'everest consulting group, inc.,',
#  'new york technology partners, inc.',
#  'sbase technologies inc',
#  'johnson controls, inc.',
#  'barclays capital inc.',
#  'brillio, llc',
#  'lawrence berkeley national laboratory',
#  'motorola solutions, inc.',
#  'alpha net consulting llc',
#  'iris software, inc.',
#  'ads alliance data systems, inc.',
#  'cloudeeva, inc',
#  'divensi inc.',
#  'capital one services ii llc',
#  'splendtek inc',
#  'xenosoft technologies, inc',
#  'ca, inc.',
#  'palvai global services inc',
#  'sdlc management, inc.',
#  'adaequare inc',
#  'first tek, inc.',
#  'northstar group inc',
#  'ntt data, inc. (formerly keane inc.)',
#  'halliburton energy services, inc.',
#  'itelligence, inc.',
#  'integrated resources, inc',
#  'iconsoft inc.',
#  'the curators of the university of missouri',
#  'delta system & software, inc',
#  'kpit infosystems inc.',
#  'uhcp d/b/a upmc mep',
#  'dgn technologies inc',
#  'groupon, inc.',
#  'dell marketing lp',
#  'infosys  limited',
#  'cigniti, inc.',
#  'zensar technologies inc.',
#  'trustees of boston university',
#  'strategic resources international, inc.',
#  'reliance global services inc.',
#  'sap labs, llc',
#  'quality matrix inc',
#  'marlabs, inc.',
#  'samsung telecommunications america, llc',
#  'orian engineers incorporated',
#  'the board of trustees of the leland stanford, jr.',
#  'imetris corporation',
#  'university of virginia',
#  'ubs securities llc',
#  'arizona state university',
#  'the trustees of princeton university',
#  'rutgers, the state university of new jersey',
#  'virginia polytechnic institute & state university',
#  'ramp technology group llc',
#  'weill cornell medical college',
#  'sysfore technologies, inc.',
#  'ncs pearson, inc.',
#  'the university of georgia',
#  'logic planet cs inc',
#  'university of rochester',
#  'technip usa, inc.',
#  'temple university--a commonwealth university',
#  'the university of texas southwestern medical cente',
#  'zylog systems ltd.',
#  'premier it solutions, inc',
#  'riverbed technology, inc.',
#  'niche software solutions inc',
#  'infogain corporation',
#  'nisum technologies inc.',
#  'fusion plus solutions, inc',
#  'etouch systems corporation',
#  'baker hughes incorporated',
#  'promatrix corp',
#  'iowa state university of science and technology',
#  'unify solutions, inc.',
#  'chevron corporation',
#  'california institute of technology',
#  'smart works, llc',
#  'north carolina state university',
#  'intel mobile communications north america',
#  'diaspark inc',
#  'ernst &amp; young u.s. llp',
#  'new york university',
#  'university of arkansas for medical sciences',
#  'astir services llc',
#  'baha industries corp.',
#  'optum services, inc.',
#  'montefiore medical center',
#  'diversant llc',
#  'st. barnabas hospital',
#  'dana-farber cancer institute',
#  'deemsys inc',
#  'sree infotech llc',
#  'capgemini america, inc.',
#  'virtue group, llc',
#  'trans american information systems inc',
#  'logistic solutions, inc.',
#  'american airlines, inc.',
#  'revereit llc',
#  'indus valley consultants, inc.',
#  'corp2corp inc',
#  'motorola mobility, inc.',
#  'frontier technologies, llc',
#  'pyramid technology solutions, inc.',
#  'qualcomm innovation center inc.',
#  'client network services, inc.',
#  'aspire systems, inc.',
#  'sapvix inc',
#  'caremark, llc',
#  'ez2 technologies, inc.',
#  'agreeya solutions, inc.',
#  'university of kentucky',
#  'washington state university',
#  'bp america inc.',
#  'aegis therapies, inc.',
#  'systems technology group, inc.',
#  'everest consulting group, inc',
#  'applied materials, inc.',
#  'state street bank and trust company',
#  'autodesk, inc.',
#  'altair productdesign, inc.',
#  'lenmar consulting inc.',
#  'tavant technologies, inc.',
#  'erp and erp corp',
#  'deutsche bank new york branch',
#  'infosmart systems inc',
#  'university of massachusetts medical school',
#  'discover products inc.',
#  'infolob solutions, inc.',
#  'globallogic,inc.',
#  'cornell university',
#  'oak ridge associated universities',
#  'wayne state university',
#  'it america inc',
#  'webilent technology inc',
#  'value consulting llc',
#  'satyam computer services, ltd.',
#  'google, inc.',
#  'aecom technical services, inc.',
#  'fedex corporate services, inc.',
#  'dataserv inc',
#  'primesoft, inc',
#  'logic planet inc',
#  'ut-battelle, llc (oak ridge national laboratory)',
#  'goldman sachs & co.',
#  'nagarro, inc.',
#  'carnegie mellon university',
#  'deloitte &amp; touche llp',
#  "st. jude children's research hospital",
#  'capital one, national association',
#  'genome international corporation',
#  'genentech, inc.',
#  'amgen inc.',
#  'azimetry inc.',
#  'usm business systems, inc.',
#  'siemens energy, inc.',
#  'georgia institute of technology',
#  'orpine, inc.',
#  'scopus consulting group inc.',
#  'epam systems, inc',
#  'larsen and toubro infotech limited',
#  'united software group inc.',
#  'universal software corporation',
#  'system soft technologies, llc',
#  'ramps international, inc',
#  'ness usa, inc.',
#  'zs associates, inc.',
#  'systime computer corporation',
#  'staples, inc.',
#  'international systems technologies, inc.',
#  'amzur technologies, inc',
#  'salesforce.com inc.',
#  "cincinnati children's hospital medical center",
#  'mu sigma, inc.',
#  'swanktek inc',
#  'softpath system llc',
#  'asta crs, inc.',
#  'manhattan associates, inc.',
#  'henry ford health system',
#  'sogeti usa, llc',
#  'virgo inc',
#  'cadence design systems, inc.',
#  'american unit, inc',
#  'onward technologies, inc',
#  'xavient information systems, inc.',
#  'paramount software solutions',
#  'collabera inc.',
#  'scm data, inc',
#  'partners healthcare',
#  'xoriant corporation',
#  'miracle software sysytems inc',
#  'tibco software, inc.',
#  'juniper networks, inc.',
#  'abbott laboratories',
#  'vision it services usa inc',
#  'cavalier it inc.',
#  'speridian technologies, llc',
#  'scepter technologies inc',
#  'coolsoft, llc',
#  'comtec consultants, inc.',
#  'cvs pharmacy, inc.',
#  'jean martin inc',
#  'environmental systems research institute, inc.',
#  'murphy-brown llc',
#  'l&t technology services, ltd.',
#  'slk america inc.',
#  'federal home loan mortgage co.',
#  'kbr, inc.',
#  'quadrant 4 system corporation',
#  'vigna solutions, inc.',
#  'the board of trustees of the leland stanford, jr. university',
#  'aditi technologies pvt. ltd.',
#  'philips electronics north america corporation',
#  'the florida state university',
#  'kellton tech inc',
#  'param consulting services, inc',
#  'lancesoft, inc.',
#  'computek soulutions inc',
#  'united healthcare services, inc.',
#  'the university of tennessee',
#  'i28 technologies corporation',
#  'cummins emission solutions inc.',
#  'sarayu consultants inc',
#  'a.t. kearney, inc.',
#  'first tek , inc.',
#  'university of maryland, baltimore',
#  'codesoft international, inc.',
#  'goldman sachs services llc',
#  'caterpillar inc',
#  'teradata operations, inc.',
#  'rapidit inc.',
#  'citigroup technology, inc.',
#  'xpedite technologies inc',
#  'synopsys, inc.',
#  'value consulting inc',
#  'pfizer inc',
#  'board of regents of the university of nebraska',
#  'lsi corporation',
#  'allied informatics, inc',
#  'uchicago argonne, llc',
#  'svk systems inc',
#  'saama technologies, inc.',
#  'seagate us llc',
#  'rehabcare group east, inc.',
#  'university of connecticut',
#  'ibm india private ltd',
#  'rs software (india) ltd.',
#  'netflix, inc.',
#  'monsanto company',
#  'new york city department of education',
#  'venturesoft global inc',
#  'the university of tennessee health science center',
#  'canvas infotech, inc.',
#  'global teachers research & resources, inc',
#  'visionet systems, inc.',
#  'hallmark global technologies inc',
#  'geo logic systems corp',
#  'kindred rehab services, inc.',
#  'prosoft it services, inc',
#  'dell marketing, lp',
#  'technology consultants inc',
#  'freescale semiconductor, inc.',
#  'university of miami-miller school of medicine',
#  'global infotech inc',
#  'vedicsoft solutions, inc.',
#  'intellect business solutions, llc',
#  'exlservice.com, llc',
#  'nihaki systems inc',
#  'conocophillips company',
#  'avnet, inc.',
#  'kronsys, inc.',
#  'airwatch, llc',
#  'jacobs engineering group inc.',
#  'rockwell collins, inc.',
#  'zylog systems limited',
#  'siritek inc',
#  'competent systems, inc',
#  'mckesson corporation',
#  'nike, inc.',
#  'agility technologies, llc',
#  'advansoft international inc',
#  'maganti it resources, llc',
#  'db global technology inc.',
#  'isr info way, inc.',
#  'corporate computer services inc',
#  'argha services, inc',
#  'tanisha systems inc',
#  'factset research systems, inc.',
#  'bronx-lebanon hospital center',
#  'rei systems inc.',
#  'caterpillar inc.',
#  'geometric americas, inc',
#  'capgemini financial services usa inc. (legacy kanbay)',
#  'nationwide insurance',
#  'university of pittsburgh physicians',
#  'the university of houston',
#  'adecco group na/modis, inc.',
#  'jpmorgan chase & co',
#  'akt, llc.',
#  'ecom consulting inc',
#  'oregon health & science university',
#  'citadel llc',
#  'shinewell technologies inc.',
#  'a1 kaiser inc',
#  'oregon state university',
#  'west virginia university',
#  'mindlance, inc.',
#  'bristol-myers squibb company',
#  'selsoft, inc.',
#  'orion systems integrators llc',
#  'spartan solutions inc',
#  'gspann technologies, inc.',
#  'neumeric technologies corporation',
#  'los alamos national security, llc',
#  'business intelli solutions, inc.',
#  'thomson reuters (markets) llc',
#  'georgetown university',
#  'iblesoft inc',
#  'mouri tech llc',
#  'v.l.s systems, inc',
#  'maxim integrated products, inc.',
#  'virginia commonwealth university',
#  'larsen & toubro infotech limted',
#  'inovalon, inc.',
#  'polaris software lab (india) limited',
#  'data, inc.',
#  'dell usa lp',
#  'enterprise solutions, inc.',
#  'university of california, irvine',
#  'texas tech university health sciences center',
#  'emeteors inc',
#  'object frontier, inc.',
#  'object technology solutions inc',
#  'fiserv global services, inc.',
#  'fidelity brokerage services llc',
#  'pamten, inc.',
#  'dew software, inc.',
#  'trinuc llc',
#  'saicon consultants, inc.',
#  'ait global, inc',
#  'openlogix corporation',
#  'netvision resources, inc',
#  'gulfstream aerospace corporation',
#  'keane, inc.',
#  'dell products l.p.',
#  'proser corporation',
#  'ved software services inc',
#  'stratedge, inc',
#  'the gap, inc.',
#  'sysintelli, inc',
#  '8k miles software services inc',
#  'tek services llc',
#  'the dow chemical company',
#  'syntel consulting inc',
#  'schneider electric usa, inc.',
#  'western digital technologies, inc.',
#  'pyramid consulting, inc.',
#  'techno-comp inc',
#  'sasken communication technologies, ltd.',
#  'amazon web services, inc.',
#  'cardinal health, inc.',
#  'collabera inc.; previously known as gci',
#  'navistar, inc.',
#  'hcl global systems, inc.',
#  'access therapies, inc.',
#  'dell usa l.p.',
#  'texas tech university',
#  'everest computers inc.',
#  'makeurcareer llc',
#  'rackspace us, inc.',
#  'axis, inc.',
#  'first object inc',
#  'jcg technologies, inc.',
#  'resource logistics, inc.',
#  'sunmerge systems inc.',
#  'california creative solutions, inc.',
#  'evantage technologies inc.,',
#  'hughes network systems llc',
#  'informatica corporation',
#  'wellpoint, inc.',
#  'sg americas securities, llc',
#  'apps solutions inc',
#  'aqua information systems, inc.',
#  'valuemomentum, inc.',
#  'slk america inc',
#  'university of hawaii',
#  'sqa concepts inc',
#  'beta soft systems, inc.',
#  'it trailblazers, llc',
#  'millennium info tech, inc.',
#  'applab systems, inc',
#  'vigilant technologies llc',
#  'synerzy software solutions inc',
#  'nemo it solutions, inc',
#  'axon solutions, inc.',
#  'musigma inc',
#  'lhp software, llc',
#  'black & veatch corporation',
#  'general electric company',
#  'amerisoftpro systems llc',
#  'ubs ag',
#  'kansas state university',
#  'vst consulting inc',
#  'tata technologies, inc.',
#  'conch technologies, inc.',
#  'the johns hopkins university',
#  'epeople technologies inc',
#  'rs software (india) ltd',
#  'visa u.s.a. inc.',
#  'prosoft technology group, inc.',
#  'seven seas technologies, inc.',
#  'patni americas, inc.',
#  'saras america inc.',
#  'anira solutions inc',
#  'bdo usa, llp',
#  'infomerica, inc.',
#  'international software systems inc',
#  'abb inc.',
#  'avani technology solutions inc.',
#  'international technologies pro, llc',
#  'it cats, llc',
#  'quality software services, inc.',
#  'majescomastek',
#  'mcafee, inc.',
#  'infomatics corp',
#  'usm business systems, inc',
#  'virgo inc.',
#  'electronic arts, inc.',
#  'jnit technologies',
#  'pioneer corporate services inc',
#  'sprint corporation',
#  'vastika, inc.',
#  'liquidhub, inc.',
#  'schweitzer engineering laboratories, inc.',
#  'deloitte financial advisory services llp',
#  'the advisory board company',
#  'oberon it, inc.',
#  'alcatel-lucent usa inc.',
#  'wells fargo bank, n.a.',
#  'national instruments corporation',
#  'new york university hospitals center',
#  'altimetrik corp',
#  'quinnox, inc.',
#  'life technologies corporation',
#  'smart source technologies, inc.',
#  'business intelli solutions inc',
#  'comprehab, inc.',
#  'albert einstein college of medicine of yeshiva uni',
#  'siemens industry, inc.',
#  'grant thornton llp',
#  'prelude systems inc.',
#  'tekwissen llc',
#  'the university of texas m.d. anderson cancer center',
#  'palo alto networks, inc.',
#  'university of notre dame du lac',
#  'louisiana state university and a & m college',
#  'avighna global solutions llc',
#  'kyyba inc.',
#  'altera corporation',
#  'aricent technologies (holdings) ltd.',
#  'national oilwell varco, l.p.',
#  'brown university',
#  'tibco software inc.',
#  'progressive casualty insurance company',
#  'barclays bank delaware',
#  'hire it people, llc',
#  'tender touch rehab services llc',
#  'data systems integration group inc.',
#  'mncl, inc.',
#  'lam research corporation',
#  'satyam-venture engineering services pvt. ltd.',
#  'eateam, inc.',
#  'lorshi systems, llc',
#  'the sherwin-williams company',
#  'trisync technologies, inc.',
#  'cybage software inc',
#  'decipher software solutions',
#  'citicorp credit services, inc. (usa)',
#  'fis management services, llc',
#  'clairvoyant technosolutions inc.',
#  'techwave consulting inc',
#  'intelliswift software, inc.',
#  'elite it solutions inc',
#  'nga group, inc.',
#  'whirlpool corporation',
#  'jackson therapy partners holdings, llc',
#  'robert bosch llc',
#  'ansys, inc.',
#  'macquarie holdings (usa) inc.',
#  'aurionpro solutions, inc.',
#  'jpmorgan chase &amp; co.',
#  'sriven systems, inc.',
#  'atos it solutions and services, inc.',
#  'rockwell automation, inc.',
#  'enternet business systems, inc',
#  'apollo group, inc.',
#  'mmc systems inc.',
#  'microstrategy incorporated',
#  'numbers only, inc.',
#  'zynga inc.',
#  'rensselaer polytechnic institute',
#  'capgemini us llc',
#  'alpha clinical systems, inc',
#  'maruthi technologies, llc',
#  'mitchell/martin, inc.',
#  'lcc international, inc.',
#  'kelly services, inc.',
#  'hewlett packard enterprise company',
#  'houston independent school district',
#  'directv llc',
#  'blackrock investment management, llc',
#  'consultadd inc',
#  'bodhtree solutions,inc',
#  'gallega software solutions inc',
#  'ana-data consulting inc',
#  'isync solutions, inc.',
#  'the university of texas at dallas',
#  'tasacom technologies, inc.',
#  'avant systems inc',
#  'beta soft systems inc',
#  'abbvie inc',
#  'ka-sapsolutions inc',
#  'business integra technology solutions inc.',
#  'cleveland clinic foundation',
#  'sunray enterprise, inc.',
#  'american technology consulting, llc',
#  'dw practice llc',
#  'redeemsoft, llc',
#  'capgemini financial services usa inc. (legacy kanb',
#  'mentor graphics corporation',
#  'the university of toledo',
#  'ventois, inc',
#  'novartis institutes for biomedical research, inc.',
#  'valtech solutions inc.',
#  'automatic data processing, inc.',
#  'shubh solutions llc',
#  'isync solutions inc',
#  'university of oklahoma',
#  'siemens medical solutions usa, inc.',
#  'sourceinfotech inc.',
#  'ultimate care inc',
#  "the children's hospital of philadelphia",
#  'esurance insurance services, inc.',
#  'university of texas medical branch at galveston',
#  'zillion technologies inc.',
#  'pristine rehab care, llc',
#  'saint louis university',
#  'fred hutchinson cancer research center',
#  'deloitte transactions and business analytics llp',
#  'hexacorp llc',
#  'marshfield clinic',
#  'the nielsen company (us), llc',
#  'american express travel related services co., inc.',
#  'tachyon technologies llc',
#  'apps associates, llc',
#  'bartronics america, inc',
#  'alphavista services, inc.',
#  'american business solutions, inc.',
#  'florida hospital',
#  'university of oklahoma health sciences center',
#  'beth israel deaconess medical center, inc.',
#  'sbp consulting inc.',
#  'amdocs, inc.',
#  'ishift corp',
#  'amirit technologies, inc.',
#  'daz systems, inc.',
#  'clear thought solutions llc',
#  'citiustech inc',
#  'northeastern university',
#  'interpro, inc.',
#  'gilead sciences, inc.',
#  'university of cincinnati',
#  'prospance, inc.',
#  'camelot integrated solutions inc',
#  'ford motor company',
#  'dish network llc',
#  'tek leaders inc',
#  'skillsight inc.',
#  'blizzard entertainment, inc.',
#  'itrace foundaiton, inc.',
#  'network objects, inc.',
#  'polaris consulting & services ltd',
#  'humetis technologies, inc.',
#  'health carousel, llc',
#  'alcatel-lucent usa inc',
#  'logic soft inc.',
#  'skoruz technologies, inc',
#  'whiz it solutions inc',
#  'dizer corp',
#  'florida international university',
#  'adroix corp',
#  'samsung information systems america, inc.',
#  'igt solutions, inc.',
#  'rush university medical center',
#  'intalent llc',
#  'national financial llc',
#  "children's national medical center",
#  'amicus systems inc',
#  'advantage technical resourcing, inc.',
#  'research in motion corporation',
#  'successfactors, inc.',
#  'imatrix corp',
#  'anthem, inc.',
#  'tekstrom inc',
#  'silicon staff it services, inc.',
#  'citadel information services inc.',
#  'first tek dos llc',
#  'community rehabilitation services inc',
#  'aztek inc',
#  'nexius solutions inc.',
#  'techstar consulting inc',
#  'nokia solutions and networks us llc',
#  'precision global consulting, inc.',
#  'softpath systems inc',
#  'intelliswift software inc',
#  'arista networks, inc.',
#  'hewitt associates llc',
#  'medical college of wisconsin',
#  'right click systems, llc',
#  'tenazx inc.',
#  'im flash technologies, llc',
#  'nic info tek inc',
#  'medical university of south carolina',
#  'dell products lp',
#  'etest it, inc.',
#  'akken inc',
#  'ubs services llc',
#  'cedent consulting inc',
#  'itcaps llc',
#  'the university of kansas',
#  'dropbox, inc.',
#  'aptiva corp',
#  'microchip technology, inc.',
#  'applexus technologies llc',
#  'econtenti inc.',
#  'infor (us), inc.',
#  'citicorp north america, inc.',
#  'worleyparsons group, inc.',
#  'latentview analytics corporation',
#  'marvell tech llc',
#  'xtglobal, inc.',
#  'estrada consulting inc',
#  'cedars-sinai medical center',
#  '3i infotech, inc',
#  'webject systems, inc.',
#  'softech international resources, inc.',
#  'comscore, inc.',
#  'university of california at santa barbara',
#  'connvertex technologies inc.',
#  'blackrock institutional trust company, n.a.',
#  'anu software consultants, inc.',
#  'globalfoundries u.s., inc.',
#  'ksoft systems inc',
#  'data-core systems, inc',
#  'teksystems global services llc',
#  'metlife group, inc.',
#  'u.s. bank national association',
#  "massachusetts general physician's organization",
#  'tabner, inc.',
#  'corning incorporated',
#  'slalom, llc',
#  'sony network entertainment international llc',
#  'ispace, inc',
#  'boston scientific corporation',
#  'state university of new york at stony brook',
#  'xilinx, inc.',
#  'quest diagnostics incorporated',
#  'trw automotive, inc.',
#  'servicenow, inc.',
#  'university of louisville',
#  'advantage it inc',
#  'tekmark global solutions llc',
#  'web yoga, inc.',
#  'oslo solutions llc',
#  'f5 networks, inc.',
#  'dartmouth college',
#  'yashco systems, inc.',
#  'cellco partnership',
#  'nixsol, inc',
#  'sgs technologie, llc',
#  'national consulting group inc',
#  "lowe's companies, inc.",
#  'gssr inc',
#  'fluor enterprises, inc.',
#  'parexel international',
#  'u.s. tech solutions, inc.',
#  'youngsoft inc.',
#  'honeywell international inc.',
#  'supreme tech solutions llc',
#  'sierra infosys, inc',
#  'virtuosa global solutions llc',
#  'food and drug administration, hhs',
#  'accenz llc',
#  'international technology solutions, inc.',
#  'morgan stanley smith barney llc',
#  'jpmorgan chase and co.',
#  'accenture technology solutions',
#  'pegaframe infotech inc',
#  'cyberbrains inc',
#  'novartis pharmaceuticals corporation',
#  'csc consulting, inc.',
#  'tech matrix inc',
#  'wright center for graduate medical education',
#  'opensoft inc',
#  'fmr co inc.',
#  'aol inc.',
#  'mastercard international incorporated',
#  'enterprise it resources, inc',
#  'mediterranean shipping company (usa), inc.',
#  '3s business corporation',
#  'mufg union bank, n.a.',
#  'w3global, inc.',
#  'anjaneyap, inc.',
#  'calsoft labs, inc.',
#  'savi technologies, inc',
#  'maimonides medical center',
#  'microinfo inc',
#  'gcom software, inc.',
#  'hadiamondstar software solutions, llc',
#  'softhq',
#  'aci infotech inc.',
#  'intriv inc',
#  'codesmart inc.',
#  ...]

# %%
len(companies)
# Out:
# 7173426

# %%
common_companies = companies[companies.name.isin(top_company_names)]

# %%
common_companies
# Out:
#          Unnamed: 0                             name             domain  \
# 17          1170519             jpmorgan chase & co.  jpmorganchase.com
# 36          6249577               ford motor company           ford.com
# 37          5872179                intel corporation          intel.com
# 80          2268961           lowe's companies, inc.          lowes.com
# 167         1368891                    merrill lynch             ml.com
# ...             ...                              ...                ...
# 7008544     3035230         university of louisville                NaN
# 7054935     6024998  north carolina state university                NaN
# 7118198     6192944       the advisory board company   advisoryboard.us
# 7122671     1416265                  cdi corporation       cdigroup.biz
# 7131060     6132308             linkedin corporation                NaN
#
#          year founded                   industry size range  \
# 17             1823.0         financial services     10001+
# 36             1903.0                 automotive     10001+
# 37             1968.0             semiconductors     10001+
# 80             1946.0                     retail     10001+
# 167            1914.0         financial services     10001+
# ...               ...                        ...        ...
# 7008544           NaN              biotechnology     1 - 10
# 7054935           NaN                        NaN     1 - 10
# 7118198        2010.0      management consulting     1 - 10
# 7122671        2002.0  marketing and advertising     1 - 10
# 7131060           NaN                        NaN     1 - 10
#
#                                            locality         country  \
# 17                new york, new york, united states   united states
# 36                dearborn, michigan, united states   united states
# 37           santa clara, california, united states   united states
# 80       mooresville, north carolina, united states   united states
# 167               new york, new york, united states   united states
# ...                                             ...             ...
# 7008544      london, greater london, united kingdom  united kingdom
# 7054935                                         NaN             NaN
# 7118198                                         NaN             NaN
# 7122671             brea, california, united states   united states
# 7131060                                         NaN             NaN
#
#                                               linkedin url  \
# 17                     linkedin.com/company/jpmorgan-chase
# 36                 linkedin.com/company/ford-motor-company
# 37                  linkedin.com/company/intel-corporation
# 80            linkedin.com/company/lowe's-home-improvement
# 167                      linkedin.com/company/merrilllynch
# ...                                                    ...
# 7008544      linkedin.com/company/oxford-stem-cell-limited
# 7054935  linkedin.com/company/north-carolina-state-univ...
# 7118198            linkedin.com/company/advisory-board-aps
# 7122671             linkedin.com/company/cdi-group-limited
# 7131060               linkedin.com/company/invalid24786831
#
#          current employee estimate  total employee estimate
# 17                           95234                   242135
# 36                           65335                   133963
# 37                           64046                   146247
# 80                           39741                    91802
# 167                          27206                   115216
# ...                            ...                      ...
# 7008544                          0                        1
# 7054935                          0                        2
# 7118198                          0                        2
# 7122671                          0                        3
# 7131060                          0                        1
#
# [389 rows x 11 columns]

# %%
remaining_companies = list(set(top_company_names) - set(common_companies["name"]))

# %%
remaining_companies_formatted = [name.replace(", inc", "") for name in remaining_companies]

# %%
remaining_companies_formatted = [name.replace(", llc", "") for name in remaining_companies_formatted]

# %%
# remaining_companies_formatted = [name.replace("inc", "") for name in remaining_companies_formatted]

# %%
remaining_companies_formatted
# Out:
# ['aptiva corp',
#  'international systems technologies.',
#  'ca.',
#  'infomerica.',
#  'general hospital corporation',
#  'sears holdings management corporation',
#  'cgi technologies and solutions inc.',
#  'synerzy software solutions inc',
#  'jpmorgan chase &amp; co.',
#  'a2z development center.',
#  'prelude systems inc.',
#  'global infotech inc',
#  'gss infotech ct.',
#  'sasken communication technologies, ltd.',
#  'vigilant technologies llc',
#  'redeemsoft',
#  'riverbed technology.',
#  'resource america information technology.',
#  'ntt data. (formerly keane inc.)',
#  'usm business systems',
#  'oberon it inc',
#  'ciber.',
#  'globalpoint.',
#  'globalfoundries u.s..',
#  'oslo solutions llc',
#  'oberon it.',
#  'mouri tech llc',
#  'tesla motors.',
#  'johnson controls.',
#  'adecco group na/modis.',
#  'vaktech corporation',
#  'logistic solutions.',
#  'american technology consulting',
#  'apps associates',
#  'sbp consulting inc.',
#  'kelly services.',
#  'amerisoftpro systems llc',
#  'hallmark global technologies inc',
#  'neumeric technologies corporation',
#  'natsoft corporation',
#  'deloitte consulting llp',
#  'satyam-venture engineering services pvt. ltd.',
#  'united software group inc.',
#  'the university of southern california',
#  'atos it solutions and services.',
#  'jcg technologies.',
#  'centraprise, corp',
#  'sysfore technologies.',
#  'gdn infotech.',
#  'pricewaterhousecoopers advisory services llc',
#  'amazon corporate llc',
#  'zynga inc.',
#  'hermitage infotech',
#  'navistar.',
#  'the university of chicago',
#  'united healthcare services.',
#  'competent systems',
#  'mindteck.',
#  'national institutes of health, hhs',
#  'indiana univ. purdue univ. indianapolis',
#  'national consulting group inc',
#  'ust global inc.',
#  'verizon data services llc',
#  'techwave consulting inc',
#  'siemens energy.',
#  'collaborate solutions inc',
#  'ntt data.',
#  'educational testing service',
#  'proficient business systems.',
#  'mitchell/martin.',
#  'db global technology inc.',
#  'temple university--a commonwealth university',
#  'baha industries corp.',
#  'palvai global services inc',
#  'randstad technologies, lp',
#  'deloitte &amp; touche llp',
#  'rockwell collins.',
#  'informatica corporation',
#  'itech us.',
#  'geometric americas',
#  'novartis institutes for biomedical research.',
#  'goldman sachs & co.',
#  'uhcp d/b/a upmc mep',
#  'state street bank and trust company',
#  'stem xpert llc',
#  'diversant llc',
#  'capgemini us llc',
#  'pristine rehab care',
#  'w3global.',
#  'iconsoft inc.',
#  'logic planet inc',
#  'dell products l.p.',
#  'orion systems integrators llc',
#  'gspann technologies.',
#  'prowise solutions.',
#  'the university of tennessee',
#  'philips electronics north america corporation',
#  'cybersource corporation',
#  'logic planet cs inc',
#  'fiserv global services.',
#  'etouch systems corporation',
#  'cardinal health.',
#  'nexius insight.',
#  'zylog systems ltd.',
#  'the board of trustees of the leland stanford, jr. university',
#  'calsoft labs.',
#  'pamten.',
#  'qualcomm atheros.',
#  'university of california, irvine',
#  'rockwell automation.',
#  'imatrix corp',
#  'kpit infosystems.',
#  'california creative solutions.',
#  'tachyon technologies llc',
#  'new york university hospitals center',
#  'spruce technology inc.',
#  'the university of texas health science center at h',
#  'persistent systems.',
#  'system soft technologies',
#  'birlasoft inc',
#  'canvas infotech.',
#  'international technology solutions.',
#  'technology consultants inc',
#  'the university of texas at dallas',
#  'aqua information systems.',
#  'wells fargo bank, n.a.',
#  'tek tree llc',
#  'inovant',
#  'board of regents of the university of nebraska',
#  'istream solutions.',
#  'ncs pearson.',
#  'home depot usa.',
#  'apex technology systems',
#  'kronsys.',
#  'synergy global systems inc',
#  'sriven systems.',
#  'microstrategy incorporated',
#  'techno-comp inc',
#  'itc infotech (usa).',
#  'deutsche bank securities inc.',
#  'gateway group technologies inc.',
#  'alpha net consulting llc',
#  'makeurcareer llc',
#  'robert bosch llc',
#  'gilead sciences.',
#  'credit suisse securities (usa) llc',
#  'the nielsen company (us)',
#  'itcaps llc',
#  'nuance communications.',
#  'proser corporation',
#  'rei systems inc.',
#  'blizzard entertainment.',
#  'twitter.',
#  'coolsoft',
#  'caterpillar inc',
#  'barclays services corp.',
#  'mastech alliance., a mastech holdings company',
#  'sap labs',
#  'htc global services inc.',
#  'bartronics america',
#  'bell info solutions',
#  'ez2 technologies.',
#  'orian engineers incorporated',
#  'schneider electric usa.',
#  'marlabs.',
#  'fred hutchinson cancer research center',
#  'marlabs',
#  'exlservice.com',
#  'hughes network systems llc',
#  'gulfstream aerospace corporation',
#  'hgst.',
#  'servicenow.',
#  'capital one services',
#  'cyberbrains inc',
#  'yelp inc.',
#  'aurionpro solutions.',
#  'infor (us).',
#  'albert einstein college of medicine of yeshiva uni',
#  'sapient corporation',
#  'techstar consulting inc',
#  'tabner.',
#  'sunmerge systems inc.',
#  'university of california, los angeles',
#  'epam systems',
#  'aegis therapies.',
#  'akt.',
#  'international technologies pro',
#  'ecom consulting inc',
#  'university of texas medical branch at galveston',
#  'orion systems integrators',
#  'it division.',
#  'teksystems global services llc',
#  'cyient.',
#  'baltimore city public school system',
#  'discover products inc.',
#  'technip usa.',
#  'windycity technologies inc',
#  'summitworks technologies inc',
#  'softpath systems inc',
#  'cerebra consulting.',
#  'selsoft.',
#  'progressive casualty insurance company',
#  'celcite management solutions',
#  'virginia polytechnic institute & state university',
#  'nisum technologies inc.',
#  'interpro.',
#  'siri infosolutions inc.',
#  'humana inc.',
#  'ims health incorporated',
#  'morgan stanley & co. llc',
#  'dish network llc',
#  'business intelli solutions inc',
#  'prospance.',
#  'novartis pharmaceuticals corporation',
#  'tanisha systems inc',
#  'trans american information systems inc',
#  'mu sigma.',
#  'comcast cable communications',
#  'yahoo! inc.',
#  'tech mahindra ( americas)',
#  'venturesoft global inc',
#  'global teachers research & resources',
#  'infosys public services.',
#  'saama technologies.',
#  'tavant technologies.',
#  'hcl america.',
#  'vensar technology inc',
#  'electronic arts.',
#  'aspire systems.',
#  'capital one services ii llc',
#  'western digital technologies.',
#  'collabera inc.; previously known as gci',
#  'seven seas technologies.',
#  'sourceinfotech inc.',
#  'csc consulting.',
#  'slk america inc',
#  'tibco software.',
#  'food and drug administration, hhs',
#  'research in motion corporation',
#  'visa u.s.a. inc.',
#  'photon infotech.',
#  'param consulting services',
#  'global data management.',
#  'kla-tencor corporation',
#  'deloitte financial advisory services llp',
#  'marvell tech llc',
#  'computek soulutions inc',
#  'everest computers inc.',
#  'thomson reuters (markets) llc',
#  'cigniti.',
#  'valtech solutions inc.',
#  'agreeya solutions.',
#  'galaxe.solutions',
#  'db services nj inc',
#  'national oilwell varco, l.p.',
#  'manhattan associates.',
#  'astir it solutions inc.',
#  'yashco systems.',
#  'intuit inc.',
#  'model n.',
#  'rjt compuquest.',
#  'hsbc bank usa, n.a.',
#  'sbase technologies inc',
#  'patni americas inc.',
#  'riot games.',
#  'factset research systems.',
#  'corp2corp inc',
#  'university of houston system',
#  'jean martin inc',
#  'freescale semiconductor.',
#  'maruthi technologies',
#  'motorola mobility.',
#  'life technologies corporation',
#  'groupon.',
#  'itrace foundation.',
#  'infotech enterprises america.',
#  'trisync technologies.',
#  'pfizer inc',
#  'the pnc financial services group.',
#  'lenmar consulting inc.',
#  'skillsight inc.',
#  'trinity consulting',
#  'rite aid corp.',
#  'valuemomentum.',
#  'citigroup technology.',
#  'the boston consulting group.',
#  'fedex corporate services.',
#  'spi management services',
#  'igt solutions.',
#  'collabera inc.',
#  'bp america inc.',
#  'lhp software',
#  '3i infotech',
#  'synechron.',
#  'data-core systems',
#  'symantec corporation',
#  'directv llc',
#  'tech mahindra (americas),inc.',
#  'orpine.',
#  '3s business corporation',
#  'ds soft tech',
#  'thoughtworks.',
#  'caremark',
#  'ericsson inc.',
#  'aruba networks.',
#  'alindus.',
#  'cadence design systems.',
#  'avani technology solutions inc.',
#  'pyramid technology solutions',
#  'hexaware technologies.',
#  'latentview analytics corporation',
#  'cirrus logic.',
#  'kforce inc.',
#  'american information technology corporation',
#  'intraedge.',
#  'citicorp north america.',
#  'barclays capital services inc.',
#  'avco consulting inc',
#  'university of miami-miller school of medicine',
#  'kellton tech inc',
#  'dell products lp',
#  'syntel consulting inc',
#  "children's hospital corporation",
#  'ramp technology group llc',
#  'capital one, national association',
#  'thinc systems',
#  '3i infotech.',
#  'motorola mobility llc',
#  'kpit infosystems inc.',
#  'vst consulting inc',
#  'hadiamondstar software solutions.',
#  'larsen & toubro infotech limited',
#  'mastercard international incorporated',
#  'overstock.com.',
#  'optum services.',
#  'bechtel oil, gas & chemicals.',
#  'bmc software.',
#  'business integra technology solutions inc.',
#  'technical strategies inc',
#  'eateam.',
#  'globallogic,inc.',
#  'dell marketing lp',
#  'rs software (india) ltd.',
#  'virtue group',
#  'polaris software lab (india) limited',
#  'state university of new york at stony brook',
#  'a1 kaiser inc',
#  'adp technology services.',
#  'dew software.',
#  'the johns hopkins university',
#  'becton, dickinson and company',
#  'mncl.',
#  'juniper networks (us).',
#  'oncorre.',
#  'capgemini financial services usa inc',
#  'advansoft international inc',
#  'macquarie holdings (usa) inc.',
#  'infinity tech group inc.',
#  'pricewaterhousecoopers, llp',
#  'geometric americas.',
#  'geo logic systems corp',
#  'itrace foundaiton.',
#  'citibank, n.a.',
#  'xenosoft technologies',
#  'quintiles.',
#  'deloitte tax llp',
#  'anu software consultants.',
#  'globalfoundries u.s. inc.',
#  'jpmorgan chase & co',
#  'broadridge financial solutions.',
#  'american express travel related services company.',
#  'cvs rx services.',
#  'netvision resources',
#  'rite pros inc',
#  'motorola solutions.',
#  'paramount software solutions',
#  'dw practice llc',
#  'bechtel oil, gas &amp; chemicals.',
#  'nvidia corporation',
#  'capgemini financial services usa inc. (legacy kanbay)',
#  'cmc americas.',
#  'prosoft technology group.',
#  "massachusetts general physician's organization",
#  'prokarma.',
#  'cisco systems.',
#  'first tek .',
#  'capgemini america inc',
#  'systems technology group.',
#  'parexel international',
#  'qualcomm incorporated',
#  'precision global consulting.',
#  'bloomberg, lp',
#  'csc covansys corporation',
#  'applexus technologies llc',
#  'sapphire technologies, lp',
#  'environmental systems research institute.',
#  'noblesoft solutions.',
#  'akken inc',
#  'infosytech solutions.',
#  'it trailblazers',
#  'abbvie inc',
#  'vedicsoft solutions.',
#  'f5 networks.',
#  'information control company',
#  'inovalon.',
#  'apollo group.',
#  'etest it.',
#  'web yoga.',
#  'lorven applications inc',
#  'cameron international corporation',
#  'c2s technologies inc',
#  'the gap.',
#  'virgo inc.',
#  'lorshi systems',
#  'citadel information services inc.',
#  'im flash technologies',
#  'mckinsey & company. united states',
#  'cb&i inc.',
#  'cloudeeva',
#  'ibm india private ltd',
#  'softnice.',
#  'quality software services.',
#  'kyyba inc.',
#  'business intelli solutions.',
#  'mavrick software and telecom services.',
#  'inspirage llc',
#  'essential technologies.,',
#  'staples.',
#  'humetis technologies.',
#  'data systems integration group inc.',
#  'palantir technologies inc.',
#  'innovative intelligent solutions llc',
#  'cleveland clinic foundation',
#  'citiustech inc',
#  'ait global',
#  'integrated resources',
#  'skoruz technologies',
#  'sogeti usa',
#  'citiustech inc.',
#  'syntel consulting inc.',
#  'deutsche bank new york branch',
#  'cnet global solutions.',
#  'chevron corporation',
#  'tata technologies.',
#  'strategic resources international.',
#  'ispace',
#  'idexcel.',
#  'new york technology partners.',
#  'information control corporation',
#  'unicorn technologies',
#  'national instruments corporation',
#  'scepter technologies inc',
#  'allied informatics',
#  'akamai technologies.',
#  'aci infotech inc.',
#  'oregon health & science university',
#  'hitachi consulting corporation',
#  'uchicago argonne',
#  'core education & consulting solutions.',
#  'resource logistics.',
#  'prolifics.',
#  'elite it solutions inc',
#  'infovision technologies inc',
#  'unify solutions.',
#  'globaltek systems llc',
#  'vsquare infotech inc.',
#  'shinewell technologies inc.',
#  'juniper networks.',
#  'first tek dos llc',
#  'polaris consulting and services ltd',
#  'xavient information systems.',
#  'hcl global systems.',
#  'google.',
#  'university of massachusetts medical school',
#  'the university of iowa',
#  'national financial llc',
#  'sdlc management.',
#  'smartplay.',
#  'zs associates.',
#  'rehabcare group east.',
#  'infosys technologies limited',
#  'maxim integrated products.',
#  'softech international resources.',
#  'swanktek inc',
#  'delphi corporation',
#  'larsen & toubro infotech limted',
#  'ksoft systems inc',
#  'genesis eldercare rehabilitation services.',
#  'amgen inc.',
#  'htc global services.',
#  'intalent llc',
#  'sunera technologies',
#  'university of notre dame du lac',
#  'worleyparsons group.',
#  'fidelity technology group llc',
#  'american express travel related services co..',
#  'lam research corporation',
#  'tech matrix inc',
#  'tech mahindra (americas) inc.',
#  'infosys  limited',
#  'object frontier.',
#  'saicon consultants.',
#  'micron technology.',
#  'connvertex technologies inc.',
#  'zylog systems limited',
#  'mediterranean shipping company (usa).',
#  'university of california, davis',
#  'dell marketing, lp',
#  'appdynamics.',
#  'mphasis corporation',
#  'argha services',
#  'the trustees of princeton university',
#  'capgemini financial services usa inc. (legacy kanb',
#  'a.t. kearney.',
#  'bank of america n.a.',
#  'people tech group inc.',
#  'university of california, berkeley',
#  'valuelabs.',
#  'ibm india pvt. ltd.',
#  'dotcom team',
#  'quinnox.',
#  'qualcomm technologies.',
#  't-mobile usa.',
#  'successfactors.',
#  'blackrock financial management.',
#  'american airlines.',
#  'vastika.',
#  'hewlett-packard company',
#  'aecom technical services.',
#  'mentor graphics corporation',
#  'health carousel',
#  'microexcel',
#  'the board of trustees of the leland stanford, jr.',
#  'blackrock investment management',
#  'nagarro.',
#  'rs software (india) ltd',
#  'l&t technology services, ltd.',
#  'barclays bank delaware',
#  'intriv inc',
#  'commvault americas.',
#  'perficient.',
#  'srs consulting inc.',
#  'majescomastek',
#  'airysoft',
#  'sgs technologie',
#  'whiz it solutions inc',
#  'goldman sachs services llc',
#  'cogent infotech corporation',
#  'mcafee.',
#  'aol inc.',
#  'university of california, san francisco',
#  'quest diagnostics incorporated',
#  'wellpoint.',
#  'comprehab.',
#  'idhasoft.',
#  'illumina.',
#  'hsbc securities (usa) inc.',
#  'pricewaterhousecoopers llp',
#  'wal-mart associates.',
#  'evantage technologies inc.,',
#  'revereit llc',
#  'slalom',
#  'aditi technologies pvt. ltd.',
#  'schweitzer engineering laboratories.',
#  'softhq',
#  'pegaframe infotech inc',
#  'the university of texas m.d. anderson cancer cente',
#  'estrada consulting inc',
#  'hp enterprise services',
#  'zillion technologies inc.',
#  'cvs pharmacy.',
#  'black & veatch corporation',
#  'broadcom corporation',
#  'cybage software inc',
#  'dell usa l.p.',
#  'sparta consulting inc.',
#  'synopsys.',
#  'autodesk.',
#  'lcc international.',
#  'university of california at santa barbara',
#  'citigroup global markets inc.',
#  'satyam computer services, ltd.',
#  'tasacom technologies.',
#  'cedent consulting inc',
#  'infostretch corporation',
#  'hewitt associates llc',
#  'applied materials.',
#  'intellect business solutions',
#  'alphavista services.',
#  'at&t services.',
#  'genpact llc',
#  'spartan solutions inc',
#  'credent technologies llc',
#  'avnet.',
#  'general motors company',
#  'ernst &amp; young u.s. llp',
#  'the university of texas m.d. anderson cancer center',
#  'eapt solutions.',
#  'qualihi software solutions inc.',
#  'john h. stroger jr. hospital of cook county',
#  'savvy info systems inc',
#  'general electric company',
#  'adroix corp',
#  'client network services.',
#  'netflix.',
#  'iblesoft inc',
#  'microchip technology.',
#  'zensar technologies inc.',
#  'arrow electronics.',
#  'ust global inc',
#  'sap america.',
#  'federal home loan mortgage co.',
#  'jrd systems.',
#  'v.l.s systems',
#  'management health systems.',
#  'systel inc of delaware',
#  'ernst & young u.s. llp',
#  "children's national medical center",
#  'vertisystem inc',
#  'the rockefeller university',
#  'genentech.',
#  'xoriant corporation',
#  'samsung telecommunications america',
#  'samsung information systems america.',
#  'meridiansoft.',
#  'morgan stanley & co. inc.',
#  'scopus consulting group inc.',
#  'onward technologies',
#  'amazon web services.',
#  'dataserv inc',
#  'hewlett packard enterprise company',
#  'webject systems.',
#  'eclinicalworks',
#  'international software systems inc',
#  'virtusa corporation',
#  'smartsoft international.',
#  'vedicsoft solutions llc',
#  'econtenti inc.',
#  'ramps international',
#  'enterprise it resources',
#  'anjaneyap.',
#  'paypal.',
#  'the university of texas southwestern medical cente',
#  'it cats',
#  'sierra infosys',
#  'ibm coorporation',
#  'community rehabilitation services inc',
#  'salesforce.com.',
#  'agility technologies',
#  'reliable software resources.',
#  'rackspace us.',
#  'larsen & toubro technology services ltd',
#  'facebook.',
#  'duke university and medical center',
#  'xilinx.',
#  'divensi inc.',
#  'system soft technologies llc',
#  'advanced micro devices.',
#  'ness usa.',
#  'alcatel-lucent usa inc',
#  'capgemini america.',
#  'infosys bpo ltd.',
#  'sabre glbl inc.',
#  'primesoft',
#  'automatic data processing.',
#  'acxiom corporation',
#  'patni americas.',
#  'sony network entertainment international llc',
#  'airwatch',
#  'vision it services usa inc',
#  'iowa state university of science and technology',
#  'amdocs.',
#  'teradata operations.',
#  'object technology solutions inc',
#  'schlumberger technology corporation',
#  'verinon technology solutions ltd.',
#  'u.s. tech solutions.',
#  'dell marketing l.p.',
#  'innocore solutions',
#  'nokia inc.',
#  'maganti it resources',
#  'ebay inc.',
#  'university of maryland college park',
#  'cignex datamatics inc',
#  'grandison management.',
#  'delasoft.',
#  'tringapps inc',
#  'usm business systems.',
#  'esurance insurance services.',
#  'frontier technologies',
#  'abbott laboratories',
#  'seagate us llc',
#  'salesforce.com inc.',
#  'diaspark.',
#  'the florida state university',
#  'trw automotive.',
#  'codesmart inc.',
#  'enternet business systems',
#  'beta soft systems.',
#  'american unit',
#  'jackson therapy partners holdings',
#  'nga group.',
#  'cognizant technology solutions u.s. corporation',
#  'aricent technologies (holdings) ltd.',
#  'mastech resourcing.',
#  'goldman, sachs & co.',
#  'conocophillips company',
#  'intellisoft technologies.',
#  'everest consulting group.,',
#  'dallas independent school district',
#  'isync solutions.',
#  'airbnb.',
#  'indsoft.',
#  'aztek inc',
#  'research corporation of the university of hawaii',
#  'ptc inc.',
#  'vcarve inc',
#  'stat9 technologies inc.',
#  'esystems.',
#  'computer sciences corporation',
#  'amdocs inc.',
#  'damian consulting inc',
#  'yash & lujan consulting.',
#  'ka-sapsolutions inc',
#  'honeywell international inc.',
#  'dropbox.',
#  'barclays capital inc.',
#  'northstar group inc',
#  'indus valley consultants.',
#  'infowave systems',
#  'ubs securities llc',
#  'virtuosa global solutions llc',
#  'dfs corporate services llc',
#  'beth israel deaconess medical center.',
#  'value consulting llc',
#  'softpath system llc',
#  'silicon staff it services.',
#  'wright center for graduate medical education',
#  'nexius solutions inc.',
#  'v-soft consulting group',
#  'the curators of the university of missouri',
#  'tekmark global solutions llc',
#  'artech information systems llc',
#  'brocade communications systems.',
#  'ubs services llc',
#  'wipro limited',
#  'amicus systems inc',
#  'volt management corp',
#  'nomura securities international.',
#  'visionet systems.',
#  'altera corporation',
#  'louisiana state university and a & m college',
#  'siemens medical solutions usa.',
#  'arista networks.',
#  'innate solutions,inc',
#  'spirent communications.',
#  'morgan stanley smith barney llc',
#  'trustek inc.',
#  'research foundation of cuny',
#  'vmware.',
#  'rapidit inc.',
#  'memorial sloan-kettering cancer center',
#  'network objects.',
#  'pvr technologies inc.',
#  'ads alliance data systems.',
#  'smart works',
#  'premier it solutions',
#  'pyramid technology solutions.',
#  'conch technologies.',
#  'the univ. of ala. at birmingham (uab)',
#  'reliance global services inc.',
#  'palo alto networks.',
#  'bodhtree solutions,inc',
#  'comtec consultants.',
#  'nomura america services',
#  'blackrock institutional trust company, n.a.',
#  'sanford clinic north',
#  'clairvoyant technosolutions inc.',
#  'uber technologies.',
#  'webilent technology inc',
#  'american business solutions.',
#  'najsoft',
#  'oasys technologies inc',
#  'alpha clinical systems',
#  'tech mahindra (americas).',
#  'emeteors inc',
#  'delta system & software',
#  'dell usa lp',
#  'deloitte transactions and business analytics llp',
#  'hadiamondstar software solutions',
#  'oak ridge associated universities',
#  'jacobs engineering group inc.',
#  'accenz llc',
#  'itelligence.',
#  'aricent technologies (holdings) limited',
#  'trustees of boston university',
#  'musigma inc',
#  'populus group llc',
#  'headstrong services llc',
#  'samsung semiconductor.',
#  'oracle america.',
#  'codesoft international.',
#  'the university of tennessee health science center',
#  'it spin inc',
#  'citicorp credit services. (usa)',
#  'stratedge',
#  'intel mobile communications north america',
#  'metlife group.',
#  'jpmorgan chase and co.',
#  'keane.',
#  'cellco partnership',
#  'erp analysts.',
#  'igate technologies inc.',
#  'oracle financial services software.',
#  'altimetrik corp',
#  'prosoft it services',
#  'ana-data consulting inc',
#  'ebs healthcare.',
#  'advent global solutions inc.',
#  'the mathworks.',
#  'saras america inc.',
#  'everest consulting group',
#  'charter global.',
#  'corporate computer services inc',
#  'anveta.',
#  'yash technologies.',
#  'polaris software lab (india) ltd.',
#  'heartland employment services',
#  'arkstek.',
#  'ultimate care inc',
#  'akhsaya inc',
#  'experis us.',
#  'sysintelli',
#  'logic bridge inc.',
#  'brillio',
#  'millennium info tech.',
#  'sprint corporation',
#  'new york city department of education',
#  'fmr co inc.',
#  'youngsoft inc.',
#  'microsoft corporation',
#  'multivision inc.',
#  'azimetry inc.',
#  'netapp.',
#  'fis management services',
#  'deloitte & touche llp',
#  'beta soft systems inc',
#  'first object inc',
#  '8k miles software services inc',
#  'nic info tek inc',
#  'software paradigms international group',
#  'massachusetts institute of technology',
#  'polaris consulting & services ltd',
#  'miracle software sysytems inc',
#  'tek services llc',
#  'ut-battelle (oak ridge national laboratory)',
#  'nokia solutions and networks us llc',
#  'nixsol',
#  'fusion plus solutions',
#  'imetris corporation',
#  'bristol-myers squibb company',
#  'trustees of the university of pennsylvania',
#  'apex technology group',
#  'mufg union bank, n.a.',
#  'scm data',
#  'tekwissen llc',
#  'google inc.',
#  'fluor enterprises.',
#  'u.s. bank national association',
#  'mindlance.',
#  'mastech., a mastech holdings. company',
#  'horizon technologies inc',
#  'dgn technologies inc',
#  'qualcomm innovation center inc.',
#  'mmc systems inc.',
#  'value consulting inc',
#  'iris software.',
#  'the sherwin-williams company']

# %%
companies[companies.name.isin(remaining_companies_formatted)]
# Out:
#          Unnamed: 0                                name  \
# 293         2492847                        epam systems
# 2031        1874735                         3i infotech
# 6162        6603279                      eclinicalworks
# 10435       4323428               im flash technologies
# 12004        576944                             brillio
# 13553       5604989  samsung telecommunications america
# 17489       2240775                    galaxe.solutions
# 20442       4934030                     apps associates
# 35707       4556421                            sap labs
# 46043       6516478                usm business systems
# 53749       7081134                     health carousel
# 60365       6777270                              ispace
# 74814       4599252                     it trailblazers
# 110214      4530271        pyramid technology solutions
# 115232      2987804                     sgs technologie
# 122820      6503736            system soft technologies
# 124341      2752257                 skoruz technologies
# 130078      2610415                premier it solutions
# 137362      1571987            everest consulting group
# 166407       841142                        virtue group
# 181158      1212799                       american unit
# 209072      3902672              hp enterprise services
# 230559      5440929        celcite management solutions
# 233006       415954                            scm data
# 282019      5534282                           primesoft
# 309781      1598873                             inovant
# 327840        73706                  hermitage infotech
# 362462       508386                  allied informatics
# 455727      5962841                 pristine rehab care
# 469838      1292578            system soft technologies
# 483664      7162225               frontier technologies
# 556070      7091084        pyramid technology solutions
# 574914       136906           enternet business systems
# 590144      2233706        intellect business solutions
# 604321      5251695                    infowave systems
# 640741      1034572                           primesoft
# 677080      3760586               apex technology group
# 733479      4478553                         smart works
# 896597      5526498             enterprise it resources
# 899385      2544618              alpha clinical systems
# 901860       716141                              slalom
# 923363      2458958                  trinity consulting
# 1397706       73458                        lhp software
# 1972445     3703756                       american unit
# 2011442     4575889                             inovant
# 2818639     3454871                           primesoft
# 2994881     1486313                     rjt compuquest.
# 3717176     4999079                            coolsoft
# 4356174     1987223                           stratedge
# 4747435      470693                              keane.
# 4871755      126660                integrated resources
# 4958930      203896                              ispace
# 6726031     5808038                           primesoft
#
#                                     domain  year founded  \
# 293                               epam.com        1993.0
# 2031                       3i-infotech.com        1993.0
# 6162                    eclinicalworks.com        1999.0
# 10435                          imflash.com        2006.0
# 12004                          brillio.com        2014.0
# 13553                                  NaN        1996.0
# 17489                           galaxe.com        1990.0
# 20442                   appsassociates.com        2002.0
# 35707                                  NaN           NaN
# 46043                       usmsystems.com        1999.0
# 53749                   healthcarousel.com        2004.0
# 60365                           ispace.com           NaN
# 74814                       ittblazers.com        1999.0
# 110214                      pyramidinc.com        1998.0
# 115232                 sgstechnologies.net        2003.0
# 122820                           sstech.us        1999.0
# 124341                          skoruz.com        2005.0
# 130078              premieritsolutions.com        1999.0
# 137362               everestconsulting.net        1997.0
# 166407                     virtuegroup.com        2002.0
# 181158                    americanunit.com        2003.0
# 209072                                 NaN           NaN
# 230559                         celcite.com        2003.0
# 233006                         scmdata.com           NaN
# 282019                        primesoft.pt        2004.0
# 309781                                 NaN           NaN
# 327840               hermitageinfotech.com           NaN
# 362462                                 NaN           NaN
# 455727                   pristinerehab.com        2009.0
# 469838                                 NaN        1999.0
# 483664                                 NaN           NaN
# 556070                                 NaN        1998.0
# 574914                                 NaN           NaN
# 590144               intellectbusiness.com        2003.0
# 604321                 infowavesystems.com        1998.0
# 640741                    thinkattitude.pt        2012.0
# 677080                   apextechgroup.com        1998.0
# 733479                       smartworks.es        2008.0
# 896597                         eitr.com.au        2010.0
# 899385            alphaclinicalsystems.com        2009.0
# 901860                       slalomprod.tv           NaN
# 923363                                 NaN           NaN
# 1397706                                NaN        2001.0
# 1972445                                NaN        2003.0
# 2011442                                NaN           NaN
# 2818639                       primesoft.us           NaN
# 2994881            goodpeoplerelations.com        2014.0
# 3717176                        coolsoft.nl        2014.0
# 4356174                      stratedge.biz        2012.0
# 4747435                   dannykeane.co.uk        2005.0
# 4871755  integratedresourcesrecruiting.com        2010.0
# 4958930                     iaf-alumni.com        2018.0
# 6726031                   primesoft.com.pe           NaN
#
#                                     industry   size range  \
# 293                        computer software       10001+
# 2031     information technology and services       10001+
# 6162                       computer software  1001 - 5000
# 10435                         semiconductors  1001 - 5000
# 12004    information technology and services  1001 - 5000
# 13553                     telecommunications  1001 - 5000
# 17489    information technology and services  1001 - 5000
# 20442    information technology and services  1001 - 5000
# 35707                      computer software   501 - 1000
# 46043    information technology and services   501 - 1000
# 53749                 hospital & health care    201 - 500
# 60365    information technology and services    201 - 500
# 74814    information technology and services    201 - 500
# 110214   information technology and services     51 - 200
# 115232   information technology and services     51 - 200
# 122820   information technology and services     51 - 200
# 124341   information technology and services     51 - 200
# 130078                     computer software     51 - 200
# 137362                     computer software     51 - 200
# 166407   information technology and services     51 - 200
# 181158   information technology and services     51 - 200
# 209072   information technology and services     51 - 200
# 230559                    telecommunications     51 - 200
# 233006   information technology and services     51 - 200
# 282019   information technology and services     51 - 200
# 309781   information technology and services     51 - 200
# 327840   information technology and services     51 - 200
# 362462   information technology and services     51 - 200
# 455727          health, wellness and fitness      11 - 50
# 469838   information technology and services      11 - 50
# 483664                     computer software      11 - 50
# 556070   information technology and services      11 - 50
# 574914                    financial services      11 - 50
# 590144   information technology and services      11 - 50
# 604321   information technology and services      11 - 50
# 640741   information technology and services      11 - 50
# 677080   information technology and services      11 - 50
# 733479                       events services      11 - 50
# 896597               staffing and recruiting      11 - 50
# 899385                     computer software      11 - 50
# 901860              motion pictures and film      11 - 50
# 923363                             insurance      11 - 50
# 1397706                    computer software       1 - 10
# 1972445  information technology and services       1 - 10
# 2011442  information technology and services       1 - 10
# 2818639  information technology and services       1 - 10
# 2994881            marketing and advertising       1 - 10
# 3717176                    computer software       1 - 10
# 4356174                 education management       1 - 10
# 4747435                               design       1 - 10
# 4871755                industrial automation       1 - 10
# 4958930                 aviation & aerospace       1 - 10
# 6726031  information technology and services       1 - 10
#
#                                            locality        country  \
# 293            newtown, pennsylvania, united states  united states
# 2031                     bombay, maharashtra, india          india
# 6162      westborough, massachusetts, united states  united states
# 10435                     lehi, utah, united states  united states
# 12004         morristown, new jersey, united states  united states
# 13553              richardson, texas, united states  united states
# 17489           somerset, new jersey, united states  united states
# 20442           acton, massachusetts, united states  united states
# 35707                                           NaN            NaN
# 46043            chantilly, virginia, united states  united states
# 53749               cincinnati, ohio, united states  united states
# 60365         el segundo, california, united states  united states
# 74814    north brunswick, new jersey, united states  united states
# 110214         indianapolis, indiana, united states  united states
# 115232         jacksonville, florida, united states  united states
# 122820                tampa, florida, united states  united states
# 124341         fullerton, california, united states  united states
# 130078             richardson, texas, united states  united states
# 137362            edison, new jersey, united states  united states
# 166407           alpharetta, georgia, united states  united states
# 181158                  plano, texas, united states  united states
# 209072                                          NaN            NaN
# 230559             herndon, virginia, united states  united states
# 233006       jersey city, new jersey, united states  united states
# 282019                                          NaN            NaN
# 309781                                          NaN            NaN
# 327840            edison, new jersey, united states  united states
# 362462               duluth, georgia, united states  united states
# 455727       diamond bar, california, united states  united states
# 469838                tampa, florida, united states  united states
# 483664          wilmington, delaware, united states  united states
# 556070         indianapolis, indiana, united states  united states
# 574914       morganville, new jersey, united states  united states
# 590144                 irving, texas, united states  united states
# 604321       rocky hill, connecticut, united states  united states
# 640741                     lisbon, lisbon, portugal       portugal
# 677080        cranston, rhode island, united states  united states
# 733479                     malaga, andalucia, spain          spain
# 896597           sydney, new south wales, australia      australia
# 899385        piscataway, new jersey, united states  united states
# 901860                                          NaN            NaN
# 923363     charlotte, north carolina, united states  united states
# 1397706            columbus, indiana, united states  united states
# 1972445                 plano, texas, united states  united states
# 2011442                                         NaN            NaN
# 2818639              secunderabad, telangana, india          india
# 2994881                                         NaN            NaN
# 3717176         louisville, kentucky, united states  united states
# 4356174        san ramon, california, united states  united states
# 4747435                                         NaN            NaN
# 4871755       grand rapids, michigan, united states  united states
# 4958930                                         NaN         israel
# 6726031                                         NaN            NaN
#
#                                               linkedin url  \
# 293                      linkedin.com/company/epam-systems
# 2031                      linkedin.com/company/3i-infotech
# 6162                   linkedin.com/company/eclinicalworks
# 10435           linkedin.com/company/im-flash-technologies
# 12004                         linkedin.com/company/brillio
# 13553    linkedin.com/company/samsung-telecommunication...
# 17489                linkedin.com/company/galaxe-solutions
# 20442                 linkedin.com/company/apps-associates
# 35707                        linkedin.com/company/sap-labs
# 46043            linkedin.com/company/usm-business-systems
# 53749                 linkedin.com/company/health-carousel
# 60365                          linkedin.com/company/ispace
# 74814                 linkedin.com/company/it-trailblazers
# 110214                 linkedin.com/company/pyramidtechsol
# 115232                linkedin.com/company/sgs-technologie
# 122820                 linkedin.com/company/systemsofttech
# 124341            linkedin.com/company/skoruz-technologies
# 130078           linkedin.com/company/premier-it-solutions
# 137362       linkedin.com/company/everest-consulting-group
# 166407                   linkedin.com/company/virtue-group
# 181158              linkedin.com/company/american-unit-inc
# 209072        linkedin.com/company/hp-enterprise-services2
# 230559   linkedin.com/company/celcite-management-solutions
# 233006                       linkedin.com/company/scm-data
# 282019                      linkedin.com/company/primesoft
# 309781                        linkedin.com/company/inovant
# 327840             linkedin.com/company/hermitage-infotech
# 362462             linkedin.com/company/allied-informatics
# 455727            linkedin.com/company/pristine-rehab-care
# 469838       linkedin.com/company/system-soft-technologies
# 483664          linkedin.com/company/frontier-technologies
# 556070   linkedin.com/company/pyramid-technology-solutions
# 574914      linkedin.com/company/enternet-business-systems
# 590144   linkedin.com/company/intellect-business-solutions
# 604321               linkedin.com/company/infowave-systems
# 640741   linkedin.com/company/think---outsourcing-with-...
# 677080      linkedin.com/company/the-apex-technology-group
# 733479                    linkedin.com/company/smart-works
# 896597        linkedin.com/company/enterprise-it-resources
# 899385         linkedin.com/company/alpha-clinical-systems
# 901860                         linkedin.com/company/slalom
# 923363             linkedin.com/company/trinity-consulting
# 1397706                  linkedin.com/company/lhp-software
# 1972445                 linkedin.com/company/american-unit
# 2011442                   linkedin.com/company/apb-inovant
# 2818639                   linkedin.com/company/primesoft_2
# 2994881         linkedin.com/company/good-people-relations
# 3717176                      linkedin.com/company/coolsoft
# 4356174                     linkedin.com/company/stratedge
# 4747435                        linkedin.com/company/keane.
# 4871755         linkedin.com/company/integrated-recruiting
# 4958930               linkedin.com/company/ispace-aerotech
# 6726031          linkedin.com/company/primesoft-consulting
#
#          current employee estimate  total employee estimate
# 293                          17180                    26118
# 2031                          4238                    12240
# 6162                          1733                     3027
# 10435                         1074                     1889
# 12004                          942                     1806
# 13553                          844                     2740
# 17489                          662                     1470
# 20442                          571                      963
# 35707                          327                      657
# 46043                          252                      499
# 53749                          215                      283
# 60365                          190                      453
# 74814                          151                      401
# 110214                         100                      204
# 115232                          96                      232
# 122820                          89                      185
# 124341                          88                      158
# 130078                          84                      158
# 137362                          79                      265
# 166407                          64                      130
# 181158                          58                      151
# 209072                          50                      148
# 230559                          44                      243
# 233006                          44                      131
# 282019                          35                      164
# 309781                          32                      123
# 327840                          30                       57
# 362462                          26                       90
# 455727                          20                       27
# 469838                          19                       32
# 483664                          19                       86
# 556070                          16                       28
# 574914                          15                       36
# 590144                          15                       27
# 604321                          14                       51
# 640741                          13                       55
# 677080                          13                       22
# 733479                          11                       22
# 896597                           9                       27
# 899385                           9                        9
# 901860                           9                       20
# 923363                           8                       17
# 1397706                          5                       10
# 1972445                          3                        9
# 2011442                          3                        3
# 2818639                          2                        9
# 2994881                          2                        3
# 3717176                          1                        3
# 4356174                          1                        4
# 4747435                          1                        3
# 4871755                          1                        1
# 4958930                          1                        1
# 6726031                          0                        1

# %%
common_companies.append(companies[companies.name.isin(remaining_companies_formatted)])
# Out:
#          Unnamed: 0                    name  \
# 17          1170519    jpmorgan chase & co.
# 36          6249577      ford motor company
# 37          5872179       intel corporation
# 80          2268961  lowe's companies, inc.
# 167         1368891           merrill lynch
# ...             ...                     ...
# 4356174     1987223               stratedge
# 4747435      470693                  keane.
# 4871755      126660    integrated resources
# 4958930      203896                  ispace
# 6726031     5808038               primesoft
#
#                                     domain  year founded  \
# 17                       jpmorganchase.com        1823.0
# 36                                ford.com        1903.0
# 37                               intel.com        1968.0
# 80                               lowes.com        1946.0
# 167                                 ml.com        1914.0
# ...                                    ...           ...
# 4356174                      stratedge.biz        2012.0
# 4747435                   dannykeane.co.uk        2005.0
# 4871755  integratedresourcesrecruiting.com        2010.0
# 4958930                     iaf-alumni.com        2018.0
# 6726031                   primesoft.com.pe           NaN
#
#                                     industry size range  \
# 17                        financial services     10001+
# 36                                automotive     10001+
# 37                            semiconductors     10001+
# 80                                    retail     10001+
# 167                       financial services     10001+
# ...                                      ...        ...
# 4356174                 education management     1 - 10
# 4747435                               design     1 - 10
# 4871755                industrial automation     1 - 10
# 4958930                 aviation & aerospace     1 - 10
# 6726031  information technology and services     1 - 10
#
#                                            locality        country  \
# 17                new york, new york, united states  united states
# 36                dearborn, michigan, united states  united states
# 37           santa clara, california, united states  united states
# 80       mooresville, north carolina, united states  united states
# 167               new york, new york, united states  united states
# ...                                             ...            ...
# 4356174        san ramon, california, united states  united states
# 4747435                                         NaN            NaN
# 4871755       grand rapids, michigan, united states  united states
# 4958930                                         NaN         israel
# 6726031                                         NaN            NaN
#
#                                          linkedin url  \
# 17                linkedin.com/company/jpmorgan-chase
# 36            linkedin.com/company/ford-motor-company
# 37             linkedin.com/company/intel-corporation
# 80       linkedin.com/company/lowe's-home-improvement
# 167                 linkedin.com/company/merrilllynch
# ...                                               ...
# 4356174                linkedin.com/company/stratedge
# 4747435                   linkedin.com/company/keane.
# 4871755    linkedin.com/company/integrated-recruiting
# 4958930          linkedin.com/company/ispace-aerotech
# 6726031     linkedin.com/company/primesoft-consulting
#
#          current employee estimate  total employee estimate
# 17                           95234                   242135
# 36                           65335                   133963
# 37                           64046                   146247
# 80                           39741                    91802
# 167                          27206                   115216
# ...                            ...                      ...
# 4356174                          1                        4
# 4747435                          1                        3
# 4871755                          1                        1
# 4958930                          1                        1
# 6726031                          0                        1
#
# [442 rows x 11 columns]

# %%
remaining_companies = list(set(top_company_names) - set(common_companies["name"]))
